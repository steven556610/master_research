# %% [markdown]
# # enviorment

# %%
# %matplotlib inline
import networkx as nx
import numpy as np
import pandas as pd
import csv
import os

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# # material process

# %%
df = pd.read_csv('D:/downloads/Census_allMon Aug 30 16_37_41 2021.csv')

# %%
df
# Out:
#     Gene Symbol                                               Name  \
# 0          A1CF                     APOBEC1 complementation factor
# 1          ABI1                                   abl-interactor 1
# 2          ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 3          ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 4         ACKR3                      atypical chemokine receptor 3
# ..          ...                                                ...
# 718      ZNF429                            zinc finger protein 429
# 719      ZNF479                            zinc finger protein 479
# 720      ZNF521                            zinc finger protein 521
# 721       ZNRF3                             zinc and ring finger 3
# 722       ZRSR2  zinc finger (CCCH type), RNA-binding motif and...
#
#      Entrez GeneId        Genome Location  Tier Hallmark  Chr Band Somatic  \
# 0          29974.0   10:50799421-50885675     2      NaN     11.23     yes
# ...

# %%
df_tier1 = df[df.Tier == 1]
df_tier2 = df[df.Tier == 2]

# %%
df_tier1
# Out:
#     Gene Symbol                                               Name  \
# 1          ABI1                                   abl-interactor 1
# 2          ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 3          ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 4         ACKR3                      atypical chemokine receptor 3
# 5         ACSL3     acyl-CoA synthetase long-chain family member 3
# ..          ...                                                ...
# 714       ZMYM2                            zinc finger protein 198
# 716      ZNF331                            zinc finger protein 331
# 717      ZNF384                 zinc finger protein 384 (CIZ/NMP4)
# 720      ZNF521                            zinc finger protein 521
# 722       ZRSR2  zinc finger (CCCH type), RNA-binding motif and...
#
#      Entrez GeneId        Genome Location  Tier Hallmark  Chr Band Somatic  \
# 1          10006.0   10:26746593-26860935     1      Yes     12.10     yes
# ...

# %%
df_cancer_type_abbr = df['Tumour Types(Somatic)']
df_cancer_type_group = df.groupby(by='Tumour Types(Somatic)')

# %%
df_cancer_type_abbr = df_cancer_type_abbr.str.split(',')
#df_cancer_type_abbr = df_cancer_type_abbr.tolist()

# %%
df_cancer_type_abbr
#df_cancer_type_abbr = set(df_cancer_type_abbr)
# Out:
# 0                                             [melanoma]
# 1                                                  [AML]
# 2                                    [CML,  ALL,  T-ALL]
# 3                                                  [AML]
# 4                                               [lipoma]
#                              ...
# 718                                                [GBM]
# 719    [lung cancer,  bladder carcinoma,  prostate ca...
# 720                                                [ALL]
# 721    [colorectal cancer,  adrenocortical carcinoma,...
# 722                                          [MDS,  CLL]
# Name: Tumour Types(Somatic), Length: 723, dtype: object

# %%
df_cancer_type_group.size()
# Out:
# Tumour Types(Somatic)
# ABC-DLBCL                                                                           1
# AL                                                                                  9
# AL, soft tissue sarcoma                                                             1
# ALCL                                                                                7
# ALCL, NSCLC, neuroblastoma, inflammatory myofibroblastic tumour, Spitzoid tumour    1
#                                                                                    ..
# uterine serous carcinoma                                                            1
# uveal melanoma                                                                      1
# uveal melanoma, breast, NSCLC, RCC                                                  1
# uveal melanoma, primary central nervous system melanocytic neoplasms                2
# uveal melanoma, thyroid cancer (PDTC and ATC), low grade serous ovarian cancer      1
# ...
